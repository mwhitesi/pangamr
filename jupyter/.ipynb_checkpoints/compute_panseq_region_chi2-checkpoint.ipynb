# %% [markdown]
# <div class="alert alert-block alert-info">
# __Name__: predict_amr_panseq_region_chi2<br/>
# __Description__: Compute chi^2 statistics for each pangenome region for PATRIC AMR data. Select K best and use presence/absence to predict AMR phenotype<br/>
# __Author__: Matthew Whiteside matthew dot whiteside at canada dot ca<br/>
# __Date__: Sept 28, 2007<br/>
# __TODO__:<br/>
# </div>

# %%
import pandas as pd
import numpy as np
import scipy as sp
import sklearn
import os
import re

# %%
os.chdir('../pangenome')

# %%
import config
import utils

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Load pangenome data
pg = utils.read_panseq(config.PANSEQ['pangenome_file'])

# %%
pg.toarray().shape
# Out:
# (342, 6841)

# %%
# Load AMR data
amrdf = utils.read_amr(config.PHENOTYPE['amr_file'])

# %%
df = pd.read_table(config.PHENOTYPE['amr_file'])
df = df[['genome_id','antibiotic','resistant_phenotype']]

df['genome_id'] = df['genome_id'].apply(str)
df['genome_id'] = df['genome_id'].apply(lambda x: re.sub(r'(\d+)\.(\d+)',r'\1_dot_\2',x))
df = df.apply(lambda s: s.astype("category"))

# %%
df
# Out:
#                   genome_id       antibiotic resistant_phenotype
# 0             85569_dot_259       ampicillin         Susceptible
# 1             85569_dot_259  chloramphenicol         Susceptible
# 2             85569_dot_259       gentamicin         Susceptible
# 3             85569_dot_259        kanamycin         Susceptible
# 4             85569_dot_259   nalidixic acid         Susceptible
# 5             85569_dot_259    spectinomycin         Susceptible
# 6             85569_dot_259     streptomycin         Susceptible
# 7             85569_dot_259    sulphonamides         Susceptible
# 8             85569_dot_259     tetracycline         Susceptible
# 9             85569_dot_259     trimethoprim         Susceptible
# 10    85569_dot_15199999999       ampicillin           Resistant
# 11    85569_dot_15199999999  chloramphenicol           Resistant
# 12    85569_dot_15199999999       gentamicin         Susceptible
# ...
